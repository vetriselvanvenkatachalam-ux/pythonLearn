# %% [markdown]
# Refernce On Tpoint

# %%
print("Hello World") ;
# Out:
# Hello World

# %% [markdown]
# DataType

# %% [markdown]
# 1) Numeric Type

# %%
"""INTEGER"""
A = 5 ;
print(A);
print(type(A))

"""FLOAT"""
B=23.3
print(B)
print(type(B));

"""COMPLEX"""
C=4+4J
print(C)
print(type(C))
# Imaginary Part 
print(C.imag)
# Real Part
print(C.real);
print(type(C))
# Out:
# 5
# <class 'int'>
# 23.3
# <class 'float'>
# (4+4j)
# <class 'complex'>
# 4.0
# 4.0
# <class 'complex'>

# %% [markdown]
# 2.Sequence Type

# %%
"""TUPLE"""
A = (1,2,3,4,5);
print(A);
print(type(A));

"""SET"""
B = {1,2,222,3,3,4,4,5,6,6}
print(B)
print(type(B))

"""dict"""
C={'key1' : 'Value',
   'Key2' : '1',
   'key3' : None ,
   'key4' : 'True'
   };
print(C)
print(type(C))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>
# {1, 2, 3, 4, 5, 6, 222}
# <class 'set'>
# {'key1': 'Value', 'Key2': '1', 'key3': None, 'key4': 'True'}
# <class 'dict'>

# %% [markdown]
# 3. Bollean

# %%
"""BOOLEAN"""
A = True
B = False
print(A)
print(B)
print(type(A))
print(type(B))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# 4 . Special Type

# %%
"""NONE TYPE"""
A = None
print(A)
print(type(A))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# 5 . Escape Character

# %%
"""New Line"""
A = "Hello\nWorld"
B = "Hello\rWorld"
C = "Hello\tWorld"
D = "Hello\"World\""
E = '\'Hello\'World'

print(A)
print(B)
print(C)
print(D)
print(E)
# Out:
# Hello
# World
# World
# Hello	World
# Hello"World"
# 'Hello'World

# %% [markdown]
# 6. Float Power 10

# %%
"""Float Power"""

A = 10e3
print(A)
print(type(A))
# Out:
# 10000.0
# <class 'float'>

# %% [markdown]
# Operator

# %% [markdown]
# 1 Arithmetic Operator

# %%
"""Addition """
A=4
B=5 
print(A+B)

"""Subraction"""
C=4
D=3
print(C-D)

"""Subraction^"""
E=3
F=2
print(E^F)

"""Multiplication"""

G=2
H=2
print(G*H)

I="Hi"
print(I*2)

"""Division"""
J=3
K=2
print(J/K)

"""Modulas"""
L=3
M=3
print(L%M)

"""Exponent"""

N=2
print(N**3)

"""FlorDivision"""
O=2
P=2
print(O//P)
# Out:
# 9
# 1
# 1
# 4
# HiHi
# 1.5
# 0
# 8
# 1
