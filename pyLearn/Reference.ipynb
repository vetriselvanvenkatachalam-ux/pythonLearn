# %% [markdown]
# Refernce On Tpoint

# %%
print("Hello World") ;
# Out:
# Hello World

# %% [markdown]
# DateType

# %% [markdown]
# 1) Numeric Type

# %%
"""INTEGER"""
A = 5 ;
print(A);
print(type(A))

"""FLOAT"""
B=23.3
print(B)
print(type(B));

"""COMPLEX"""
C=4+4J
print(C)
print(type(C))
# Imaginary Part 
print(C.imag)
# Real Part
print(C.real);
print(type(C))
# Out:
# 5
# <class 'int'>
# 23.3
# <class 'float'>
# (4+4j)
# <class 'complex'>
# 4.0
# 4.0
# <class 'complex'>
