# %% [markdown]
# Refernce On Tpoint

# %%
print("Hello World") ;
# Out:
# Hello World

# %% [markdown]
# DateType

# %% [markdown]
# 1) Numeric Type

# %%
"""INTEGER"""
A = 5 ;
print(A);
print(type(A))

"""FLOAT"""
B=23.3
print(B)
print(type(B));

"""COMPLEX"""
C=4+4J
print(C)
print(type(C))
# Imaginary Part 
print(C.imag)
# Real Part
print(C.real);
print(type(C))
# Out:
# 5
# <class 'int'>
# 23.3
# <class 'float'>
# (4+4j)
# <class 'complex'>
# 4.0
# 4.0
# <class 'complex'>

# %% [markdown]
# 2.Sequence Type

# %%
"""TUPLE"""
A = (1,2,3,4,5);
print(A);
print(type(A));

"""SET"""
B = {1,2,222,3,3,4,4,5,6,6}
print(B)
print(type(B))

"""dict"""
C={'key1' : 'Value',
   'Key2' : '1',
   'key3' : None ,
   'key4' : 'True'
   };
print(C)
print(type(C))
# Out:
# (1, 2, 3, 4, 5)
# <class 'tuple'>
# {1, 2, 3, 4, 5, 6, 222}
# <class 'set'>
# {'key1': 'Value', 'Key2': '1', 'key3': None, 'key4': 'True'}
# <class 'dict'>

# %% [markdown]
# 3. Bollean

# %%
"""BOOLEAN"""
A = True
B = False
print(A)
print(B)
print(type(A))
print(type(B))
# Out:
# True
# False
# <class 'bool'>
# <class 'bool'>

# %% [markdown]
# 4 . Special Type

# %%
"""NONE TYPE"""
A = None
print(A)
print(type(A))
# Out:
# None
# <class 'NoneType'>

# %% [markdown]
# 5 . Escape Character

# %%
"""New Line"""
A = "Hello\nWorld"
B = "Hello\rWorld"
C = "Hello\tWorld"
D = "Hello\"World\""
E = '\'Hello\'World'

print(A)
print(B)
print(C)
print(D)
print(E)
# Out:
# Hello
# World
# World
# Hello	World
# Hello"World"
# 'Hello'World
